# %% [markdown]
# # Wine Classification
# In this dataset, instead of trying to predict the quality of the wine based on it's characteristics, we'll be trying to distinguish red wine vs. white wine. You should already have the red wine dataset, go into the class data folder for the white wine dataset.
#
# To upload your dataset, open up the menu on the left side of the screen, click the "files" tab, and click the upload icon.

# %%
'''
A bunch of imports.

The csv library is for reading ".csv" files (things like spreadsheets)
keras is our main library for machine learning
numpy is short for number python, and it's a really nice library for all things
mathematical.

Mattplotlib.pyplot is plotting software we'll be using.
'''
import csv
import keras
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Processing Data

# %%
'''
This is a function I wrote to read csv files.
Understanding this isn't too important; please skip over it for now.
'''
def read_csv(file_name):
  data = []
  
  with open(file_name) as file:
    header = file.readline()
    
    def readline(string):
      string = string.replace('"', '')
      string = string.replace('\n', '')
      array = string.split(';')
      
      return array
    
    header = readline(header)
    
    for line in file:
      data_point = readline(line)
      data_point = [(float)(number) for number in data_point]
      data.append(data_point)
  
  return header, data

def display(header, data):
  import pandas as pd
  import copy
  total_data = [[header[i] for i in range(len(header))]] + copy.deepcopy(data)
  df = pd.DataFrame(total_data)
  print(df.head())

# %% [markdown]
# Let's parse the data and understand it:

# %%
'''
Here's our data. white_wine is a 2D list:
 
[[a0, a1, a2, a3, a4, a5, ..., a11],
 [b0, b1, b2, b3, b4, b5, ..., b11],
 [c0, c1, c2, c3, c4, c5, ..., c11], ...]

In this situation, each row [a0, a1, ..., a12] represents an example of a bottle of wine.
Each column a0, b0, c0, ..., etc. represents a "feature" or an aspect of that wine.

For example, a0 represents the "fixed acidity" of the first example. b0 represents
the "fixed acidity" of the second example, etc.
'''

header, white_wine = read_csv("white_wine.csv")
header, red_wine = read_csv("red_wine.csv")

# %%
'''
Just displaying our data
'''

display(header, white_wine)
display(header, red_wine)
# Out:
#               0                 1            2               3          4   \
# 0  fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 1              7              0.27         0.36            20.7      0.045
# 2            6.3               0.3         0.34             1.6      0.049
# 3            8.1              0.28          0.4             6.9       0.05
# 4            7.2              0.23         0.32             8.5      0.058
#
#                     5                     6        7     8          9   \
# 0  free sulfur dioxide  total sulfur dioxide  density    pH  sulphates
# 1                   45                   170    1.001     3       0.45
# 2                   14                   132    0.994   3.3       0.49
# 3                   30                    97   0.9951  3.26       0.44
# 4                   47                   186   0.9956  3.19        0.4
#
#         10       11
# 0  alcohol  quality
# 1      8.8        6
# 2      9.5        6
# 3     10.1        6
# 4      9.9        6
#               0                 1            2               3          4   \
# 0  fixed acidity  volatile acidity  citric acid  residual sugar  chlorides
# 1            7.4               0.7            0             1.9      0.076
# 2            7.8              0.88            0             2.6      0.098
# 3            7.8              0.76         0.04             2.3      0.092
# 4           11.2              0.28         0.56             1.9      0.075
#
#                     5                     6        7     8          9   \
# 0  free sulfur dioxide  total sulfur dioxide  density    pH  sulphates
# 1                   11                    34   0.9978  3.51       0.56
# 2                   25                    67   0.9968   3.2       0.68
# 3                   15                    54    0.997  3.26       0.65
# 4                   17                    60    0.998  3.16       0.58
#
#         10       11
# 0  alcohol  quality
# 1      9.4        5
# 2      9.8        5
# 3      9.8        5
# 4      9.8        6

# %%
'''
Now we concatenate the two datasets and make a corresponding "answers" list. 
A value of 0 means "not red wine" and a value of 1 means "red wine"
'''

'''
data is a 2D array containing all the elements of white_wine and red_wine
The order is preserved, so first it's the elements of white_wine and then the
elements of red_wine
'''
data = white_wine + red_wine

'''
We make a corresponding answers array. The answer to data[i] is answers[i]. And
answers[i] is either [0] if the wine is white wine, and [1] if the wine is red wine.
'''
answers = [[0] for i in range(len(white_wine))] + [[1] for i in range(len(red_wine))]

# cast to numpy arrays
data = np.array(data).astype("float64")
answers = np.array(answers).astype("float64")

# %%
'''
Now we just shuffle the arrays. Note that it only shuffles the elements one layer
deep. So if we have [[1, 2], [3, 4]], we might get [[3, 4], [1, 2]] but never
[[4, 3], [1, 2]].

np.random.seed(0) makes sure that numpy shuffles our arrays in the same way.
Basically, a "seed" is a starting point for generating random numbers.

So if you do np.random.seed(0) and then print(np.random.randint(0, 100)), it will
always be 44. 

Likewise, if we have x = [a1, a2, a3, a4] and we do np.random.seed(0) and np.random.shuffle(x)
Then x will always be transformed to [a3, a4, a2, a1].
'''

np.random.seed(0)
np.random.shuffle(data)

np.random.seed(0)
np.random.shuffle(answers)

# %%
'''
Let's look at some pictures!
'''

# Usually matplotlib uses Tkinter, which doesn't work on notebooks. This "magic
# function" with the % in front of it signals to not use Tkinter.
# %matplotlib inline

# We take the first 100 elements of our data and the corresponding 100 answers.
x_plot = data[0:100]
y_plot = answers[0:100]

# Given the ith datapoint, we want to plot datapoint[idx] over 0 or 1 depending
# on if it's red wine or not. (1 is red wine)
idx = 9

# Just going through our data and taking the (idx)th element of each datapoint.
# Again, if idx = 10, it's alcohol, if idx = 7 it's density, etc.
# (Look at the labels when we display the data)
data_plot = [data_point[idx] for data_point in x_plot]

# Just creates a scatter plot. Regular plt.plot(data_plot, y_plot) gives you a
# line graph, which is bad.
plt.scatter(data_plot, y_plot)

# %% [markdown]
# ## Building A Model

# %%
'''
We create a simple Sequential keras model. A Sequential object is the framework
for models in keras. Right now our Sequential model is empty, so it won't do
anything. We'll need to add things into it first.
'''

model = keras.models.Sequential()

# %%
'''
A "Dense" object is keras' version of linear regression. But now, since we want
logistic regression, we need to apply the sigmoid function after the linear
regression.

To do this, we set activation = "sigmoid"
'''

# The activation function is what we do after we apply the weighted sum.
# Usually, we just have y = w0x0 + w1x1 + ... + w11x11 + b, but with the activation
# keras does y = sigmoid(w0x0 + w1x1 + ... + w11x11 + b) for us.

# Of course, 'sigmoid' is preprogrammed; and there are a few others, but that's for later
log_regressor = keras.layers.Dense(1, input_shape=(12,), activation='sigmoid')

# Now we add the logistic regression "layer" to our model. It might not make sense
# right now, but remember, keras is designed to do neural networks not just 
# linear or logistic regression. The current keras design allows for generalizations
# of more than one "layer" in a model; we're just not doing any of that.
model.add(log_regressor)

# %%
'''
We need to compile a model before we run it. "opt" here is an optimizer, basically
a way of getting better. Here, we let opt = Adam, which stands for Adaptive momentum estimation.
(A Glorified version of Gradient Descent)

lr here means "learning rate." This is the step size of your gradient descent. 
If the model isn't training fast enough, try increasing it. If the model is getting
worse, try decreasing it.

Loss is mean squared error. This is what we try to minimize.
'''
opt = keras.optimizers.Adam(lr = 0.003)
model.compile(optimizer=opt, loss='mean_squared_error', metrics=['mean_absolute_error'])

# %%
'''
The line
--history = model.fit(X, y, epochs = 100)--
stores the history of how the model learned in a variable called history

(Look below for an explanation of the output.)
'''
history = model.fit(data, answers, epochs = 100)
# Out:
# Epoch 1/100
# 6497/6497 [==============================] - 1s 95us/step - loss: 0.7564 - mean_absolute_error: 0.7601
# Epoch 2/100
# 6497/6497 [==============================] - 0s 30us/step - loss: 0.7539 - mean_absolute_error: 0.7547
# Epoch 3/100
# 6497/6497 [==============================] - 0s 30us/step - loss: 0.7539 - mean_absolute_error: 0.7544
# Epoch 4/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7539 - mean_absolute_error: 0.7543
# Epoch 5/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7542
# Epoch 6/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7541
# Epoch 7/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7541
# Epoch 8/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7541
# Epoch 9/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7539 - mean_absolute_error: 0.7541
# Epoch 10/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 11/100
# 6497/6497 [==============================] - 0s 27us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 12/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 13/100
# 6497/6497 [==============================] - 0s 27us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 14/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 15/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 16/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 17/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 18/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 19/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 20/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 21/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 22/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 23/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 24/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 25/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 26/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 27/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7539
# Epoch 28/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7539
# Epoch 29/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7539
# Epoch 30/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7539
# Epoch 31/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7539
# Epoch 32/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7539
# Epoch 33/100
# 6497/6497 [==============================] - 0s 31us/step - loss: 0.7539 - mean_absolute_error: 0.7539
# Epoch 34/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7539
# Epoch 35/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7539
# Epoch 36/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 37/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7539
# Epoch 38/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 39/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7539
# Epoch 40/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 41/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 42/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 43/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 44/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7539
# Epoch 45/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 46/100
# 6497/6497 [==============================] - 0s 27us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 47/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 48/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 49/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7541
# Epoch 50/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7541
# Epoch 51/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7540
# Epoch 52/100
# 6497/6497 [==============================] - 0s 27us/step - loss: 0.7539 - mean_absolute_error: 0.7541
# Epoch 53/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7541
# Epoch 54/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7539 - mean_absolute_error: 0.7543
# Epoch 55/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7539 - mean_absolute_error: 0.7542
# Epoch 56/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7544
# Epoch 57/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7543
# Epoch 58/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7543
# Epoch 59/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7543
# Epoch 60/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7539 - mean_absolute_error: 0.7546
# Epoch 61/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7538 - mean_absolute_error: 0.7544
# Epoch 62/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7538 - mean_absolute_error: 0.7548
# Epoch 63/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7538 - mean_absolute_error: 0.7547
# Epoch 64/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7538 - mean_absolute_error: 0.7547
# Epoch 65/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7538 - mean_absolute_error: 0.7547
# Epoch 66/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7537 - mean_absolute_error: 0.7546
# Epoch 67/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7538 - mean_absolute_error: 0.7546
# Epoch 68/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7538 - mean_absolute_error: 0.7547
# Epoch 69/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7537 - mean_absolute_error: 0.7548
# Epoch 70/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.7537 - mean_absolute_error: 0.7548
# Epoch 71/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7537 - mean_absolute_error: 0.7548
# Epoch 72/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.7537 - mean_absolute_error: 0.7551
# Epoch 73/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.1662 - mean_absolute_error: 0.1884
# Epoch 74/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.0522 - mean_absolute_error: 0.0721
# Epoch 75/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.0462 - mean_absolute_error: 0.0696
# Epoch 76/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0388 - mean_absolute_error: 0.0743
# Epoch 77/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0324 - mean_absolute_error: 0.0797
# Epoch 78/100
# 6497/6497 [==============================] - 0s 29us/step - loss: 0.0308 - mean_absolute_error: 0.0799
# Epoch 79/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0293 - mean_absolute_error: 0.0773
# Epoch 80/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0289 - mean_absolute_error: 0.0727
# Epoch 81/100
# 6497/6497 [==============================] - 0s 27us/step - loss: 0.0263 - mean_absolute_error: 0.0727
# Epoch 82/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0253 - mean_absolute_error: 0.0708
# Epoch 83/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0242 - mean_absolute_error: 0.0691
# Epoch 84/100
# 6497/6497 [==============================] - 0s 27us/step - loss: 0.0233 - mean_absolute_error: 0.0682
# Epoch 85/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0233 - mean_absolute_error: 0.0685
# Epoch 86/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0225 - mean_absolute_error: 0.0663
# Epoch 87/100
# 6497/6497 [==============================] - 0s 30us/step - loss: 0.0225 - mean_absolute_error: 0.0654
# Epoch 88/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0219 - mean_absolute_error: 0.0644
# Epoch 89/100
# 6497/6497 [==============================] - 0s 30us/step - loss: 0.0211 - mean_absolute_error: 0.0624
# Epoch 90/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0205 - mean_absolute_error: 0.0618
# Epoch 91/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0209 - mean_absolute_error: 0.0615
# Epoch 92/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0202 - mean_absolute_error: 0.0597
# Epoch 93/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0208 - mean_absolute_error: 0.0598
# Epoch 94/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0198 - mean_absolute_error: 0.0585
# Epoch 95/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0194 - mean_absolute_error: 0.0579
# Epoch 96/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0194 - mean_absolute_error: 0.0572
# Epoch 97/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0199 - mean_absolute_error: 0.0577
# Epoch 98/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0187 - mean_absolute_error: 0.0560
# Epoch 99/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0186 - mean_absolute_error: 0.0554
# Epoch 100/100
# 6497/6497 [==============================] - 0s 28us/step - loss: 0.0186 - mean_absolute_error: 0.0544

# %%
'''
Explanation of the output:

Epoch 24/100
6497/6497 [==============================] - 0s 36us/step - loss: 0.0185 - mean_absolute_error: 0.0308

An epoch is a runthrough of the data. We can see that this is the 24th epoch out of the 100
which it plans to run.

6497 is the total number of examples in our data. To finish an epoch, the model has 
to train on all 6497 datapoints.

loss: 0.0185 This is the average of the squared error for each datapoint. Note that
it uses squared error because we set loss = 'mean_squared_error' when compiling.

mean_absolute_error: 0.0308. This is an error metric we can kinda understand.
On average, it's guesses are around 0.0308 off the right answer.

So, for instance, if the bottle of wine is red wine, on average, it might gueses a 0.97
or a 97% chance that it's red wine.
'''

# %%
'''
But so far our model has been doing regression; it only becomes classification
once we decide how to classify things. For our purposes, we set the classification
threshold to be 0.5. If the bottle has a more than 50% chance of being red wine, we 
classify it as red wine. If the bottle has less than a 50% chance of being red wine,
we classify it as white wine.
'''

def classify(model, X):
  # First we run the data through the model to get the probabilities of being red wine
  y = model.predict(X)
  
  # np.rint here stands for "round int". Basically, it takes any decimal and rounds
  # to the nearest integer. So 0.75, for example, goes to 1.
  y_classify = np.rint(y)
  
  # We'll see very soon a visual representation of these results.
  return y_classify

# %%
model.get_weights()
# Out:
# [array([[ 0.5677915 ],
#         [ 5.723476  ],
#         [-2.12247   ],
#         [-0.13219377],
#         [ 9.313137  ],
#         [ 0.03179574],
#         [-0.05007028],
#         [ 0.3452335 ],
#         [ 0.3308507 ],
#         [ 4.729049  ],
#         [-0.6150977 ],
#         [-0.04691073]], dtype=float32), array([-0.22332986], dtype=float32)]

# %% [markdown]
# ## Displaying Results
# Time to see how we're doing!

# %%
# Again, this is the "magic function" which enables matplotlib to work in a notebook.
# %matplotlib inline

# We'll plot only the first 50 points; plotting all 6500 datapoints will make our
# graphs incomprehendible.
x_subset = data[0:50]
y_subset = answers[0:50]

# %%
index1 = 5

# Plot the predictions of the model vs the actual answers
y_guess = model.predict(x_subset)

# Here, we extract the feature point which we want to plot against. if index1 = 0,
# for example, then we're plotting y against "fixed_acidity"
x_plot = [data_point[index1] for data_point in x_subset]
# Comprehension questions: why do we need to plot against x_plot, why not plot against x_subset?

# Plot the guesses (blue)
plt.scatter(x_plot, y_guess, label = 'Guess')
# Plot the real values (green)
plt.scatter(x_plot, y_subset, label = 'Real Value')
# Label the plot and make a legend
plt.xlabel('Fixed Acidity')
plt.ylabel('Wine Quality')
plt.legend()

# %%
#You can change this around
index2 = 6

# Plot the impact of the different features vs the actual answers
# We do this by setting all features equal to zero except for the one we're interested in
x_input = []

for i in range(len(x_subset)):
  # Create an artificial datapoint with all values = 0
  data_point = [0 for i in range(12)]
  # Set the index2 element to not zero. This will isolate the impact that index2
  # gives us.
  data_point[index2] = x_subset[i][index2]
  x_input.append(data_point)

# Convert to numpy array bc you can only predict on numpy arrays.
x_input = np.array(x_input)

# Strip away all the features except for the one we're interested in.
# (Can't plot a 12-dimensional vector in a 2D plot)
x_plot = [x_input[i][index2] for i in range(len(x_input))]

# Make guesses based on our skewed dataset
y_guess = model.predict(x_input)

# Plot the guesses and the real values.
plt.scatter(x_plot, y_guess) # Guesses = blue
plt.scatter(x_plot, y_subset) # Real values = green

# First note the sigmoid-shaped curve. Why is this?
# Second, does more "fixed acidity" mean white or red wine?

# %% [markdown]
# ### Plotting Classification
# So far, we've only been plotting continuous values; those are easier to graph. Instead, now let's try to plot discrete values.

# %%
# Now we can compare our guesses with our answers!
# classify is a function, written above which rounds our probabilities to the
# nearest number. The rounding makes logistic regression "classification".
guesses = classify(model, data)

# Let's just try comparing a few of them.
print(guesses[0:5])
print(answers[0:5])
# Out:
# [[1.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]]
# [[1.]
#  [1.]
#  [0.]
#  [0.]
#  [0.]]

# %%
# Hopefully you're model's doing well!
# Now let's try to plot results over the whole dataset.

ww = 0 #Stands for: white wine, guessed white wine.
rr = 0 #Stands for: red wine, guessed red wine.
wr = 0 #Stands for: white wine, guessed red wine.
rw = 0 #Stands for: red wine, guessed white wine.

for i in range(len(answers)):
  if answers[i][0] == 0 and guesses[i][0] == 0:
    ww += 1
  elif answers[i][0] == 1 and guesses[i][0] == 1:
    rr += 1
  elif answers[i][0] == 0 and guesses[i][0] == 1:
    wr += 1
  else:
    rw += 1

# %%
# Let's plot the confusion matrix!

print("        Guesses:   White Wine    Red Wine")
print("Truth")
print("White Wine:           {}            {}".format(ww, wr))
print("Red Wine:             {}            {}".format(rw, rr))
# Out:
#         Guesses:   White Wine    Red Wine
# Truth
# White Wine:           4842            56
# Red Wine:             86            1513

# %%
'''
Hopefully things are doing well! This matrix is very useful to plot, and can be 
extended to multi-class classification.
'''

# %% [markdown]
# # Breast Cancer Classification
# Now try applying implementing it yourself!

# %% [markdown]
# ## Processing Data

# %%
'''
Sklearn is just another machine learning library. We're just stealing it's dataset.
'''

from sklearn import datasets

breast_cancer = datasets.load_breast_cancer()

# %%
'''
Let's see what sklearn says about the dataset.
'''
print(breast_cancer['DESCR'])
# Out:
# Breast Cancer Wisconsin (Diagnostic) Database
# =============================================
#
# Notes
# -----
# Data Set Characteristics:
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         largest values) of these features were computed for each image,
#         resulting in 30 features.  For instance, field 3 is Mean Radius, field
#         13 is Radius SE, field 23 is Worst Radius.
#
#         - class:
#                 - WDBC-Malignant
#                 - WDBC-Benign
#
#     :Summary Statistics:
#
#     ===================================== ====== ======
#                                            Min    Max
#     ===================================== ====== ======
#     radius (mean):                        6.981  28.11
#     texture (mean):                       9.71   39.28
#     perimeter (mean):                     43.79  188.5
#     area (mean):                          143.5  2501.0
#     smoothness (mean):                    0.053  0.163
#     compactness (mean):                   0.019  0.345
#     concavity (mean):                     0.0    0.427
#     concave points (mean):                0.0    0.201
#     symmetry (mean):                      0.106  0.304
#     fractal dimension (mean):             0.05   0.097
#     radius (standard error):              0.112  2.873
#     texture (standard error):             0.36   4.885
#     perimeter (standard error):           0.757  21.98
#     area (standard error):                6.802  542.2
#     smoothness (standard error):          0.002  0.031
#     compactness (standard error):         0.002  0.135
#     concavity (standard error):           0.0    0.396
#     concave points (standard error):      0.0    0.053
#     symmetry (standard error):            0.008  0.079
#     fractal dimension (standard error):   0.001  0.03
#     radius (worst):                       7.93   36.04
#     texture (worst):                      12.02  49.54
#     perimeter (worst):                    50.41  251.2
#     area (worst):                         185.2  4254.0
#     smoothness (worst):                   0.071  0.223
#     compactness (worst):                  0.027  1.058
#     concavity (worst):                    0.0    1.252
#     concave points (worst):               0.0    0.291
#     symmetry (worst):                     0.156  0.664
#     fractal dimension (worst):            0.055  0.208
#     ===================================== ====== ======
#
#     :Missing Attribute Values: None
#
#     :Class Distribution: 212 - Malignant, 357 - Benign
#
#     :Creator:  Dr. William H. Wolberg, W. Nick Street, Olvi L. Mangasarian
#
#     :Donor: Nick Street
#
#     :Date: November, 1995
#
# This is a copy of UCI ML Breast Cancer Wisconsin (Diagnostic) datasets.
# https://goo.gl/U2Uwz2
#
# Features are computed from a digitized image of a fine needle
# aspirate (FNA) of a breast mass.  They describe
# characteristics of the cell nuclei present in the image.
#
# Separating plane described above was obtained using
# Multisurface Method-Tree (MSM-T) [K. P. Bennett, "Decision Tree
# Construction Via Linear Programming." Proceedings of the 4th
# Midwest Artificial Intelligence and Cognitive Science Society,
# pp. 97-101, 1992], a classification method which uses linear
# programming to construct a decision tree.  Relevant features
# were selected using an exhaustive search in the space of 1-4
# features and 1-3 separating planes.
#
# The actual linear program used to obtain the separating plane
# in the 3-dimensional space is that described in:
# [K. P. Bennett and O. L. Mangasarian: "Robust Linear
# Programming Discrimination of Two Linearly Inseparable Sets",
# Optimization Methods and Software 1, 1992, 23-34].
#
# This database is also available through the UW CS ftp server:
#
# ftp ftp.cs.wisc.edu
# cd math-prog/cpo-dataset/machine-learn/WDBC/
#
# References
# ----------
#    - W.N. Street, W.H. Wolberg and O.L. Mangasarian. Nuclear feature extraction
#      for breast tumor diagnosis. IS&T/SPIE 1993 International Symposium on
#      Electronic Imaging: Science and Technology, volume 1905, pages 861-870,
#      San Jose, CA, 1993.
#    - O.L. Mangasarian, W.N. Street and W.H. Wolberg. Breast cancer diagnosis and
#      prognosis via linear programming. Operations Research, 43(4), pages 570-577,
#      July-August 1995.
#    - W.H. Wolberg, W.N. Street, and O.L. Mangasarian. Machine learning techniques
#      to diagnose breast cancer from fine-needle aspirates. Cancer Letters 77 (1994)
#      163-171.

# %%
x_bc = breast_cancer['data']
y_bc = breast_cancer['target']

# Just going to normalize our data.
x_bc = keras.utils.normalize(x_bc)

# %%
mal = 0
ben = 0
for i in range(len(y_bc)):
  if y_bc[i] == 0:
    ben += 1
  else:
    mal += 1
print(len(y_bc))
print(mal)
print(ben)
# Out:
# 569
# 357
# 212

# %% [markdown]
# ## Building A Model
# Try building your own model! If you have questions, try refering to the "Building a Model" section in the wine classification step. If you have any more questions, ask Joshua or Oliver!
#
# Disclaimer: keras is a library which does keep many things "under the hood." You just need to follow it's rules, and it'll magically do the Gradient descent stuff for you. The lecture is meant to teach you the intuition behind keras' actions, but the implementation time is meant to show how exactly do you use keras.
#
# The keras documentation is here: [keras.io](https://keras.io)

# %%
# Try building your own model!

model = keras.models.Sequential()
model.add(keras.layers.Dense(1, input_shape = (30,), activation = 'sigmoid'))

# %%
opt = keras.optimizers.Adam(lr = 0.01)
model.compile(optimizer=opt, loss='mse', metrics=['mean_absolute_error'])

# %% [markdown]
# ## Displaying Results
# Now, display whichever results are useful to you. We recommend printing out your confusion matrix first.

# %%
history = model.fit(x_bc, y_bc, epochs = 300)
# Out:
# Epoch 1/300
# 569/569 [==============================] - 0s 719us/step - loss: 0.0513 - mean_absolute_error: 0.1319
# Epoch 2/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0513 - mean_absolute_error: 0.1322
# Epoch 3/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0513 - mean_absolute_error: 0.1322
# Epoch 4/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0512 - mean_absolute_error: 0.1311
# Epoch 5/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0512 - mean_absolute_error: 0.1314
# Epoch 6/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0512 - mean_absolute_error: 0.1315
# Epoch 7/300
# 569/569 [==============================] - 0s 35us/step - loss: 0.0512 - mean_absolute_error: 0.1322
# Epoch 8/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0513 - mean_absolute_error: 0.1324
# Epoch 9/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0514 - mean_absolute_error: 0.1311
# Epoch 10/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0513 - mean_absolute_error: 0.1318
# Epoch 11/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0514 - mean_absolute_error: 0.1315
# Epoch 12/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0512 - mean_absolute_error: 0.1316
# Epoch 13/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0512 - mean_absolute_error: 0.1320
# Epoch 14/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0513 - mean_absolute_error: 0.1313
# Epoch 15/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0512 - mean_absolute_error: 0.1314
# Epoch 16/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0512 - mean_absolute_error: 0.1314
# Epoch 17/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0511 - mean_absolute_error: 0.1314
# Epoch 18/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0512 - mean_absolute_error: 0.1319
# Epoch 19/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0512 - mean_absolute_error: 0.1314
# Epoch 20/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0511 - mean_absolute_error: 0.1314
# Epoch 21/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0511 - mean_absolute_error: 0.1315
# Epoch 22/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0511 - mean_absolute_error: 0.1319
# Epoch 23/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0511 - mean_absolute_error: 0.1317
# Epoch 24/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0512 - mean_absolute_error: 0.1313
# Epoch 25/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0511 - mean_absolute_error: 0.1313
# Epoch 26/300
# 569/569 [==============================] - 0s 44us/step - loss: 0.0512 - mean_absolute_error: 0.1319
# Epoch 27/300
# 569/569 [==============================] - 0s 47us/step - loss: 0.0512 - mean_absolute_error: 0.1322
# Epoch 28/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0511 - mean_absolute_error: 0.1315
# Epoch 29/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0512 - mean_absolute_error: 0.1311
# Epoch 30/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0511 - mean_absolute_error: 0.1313
# Epoch 31/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0511 - mean_absolute_error: 0.1312
# Epoch 32/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0511 - mean_absolute_error: 0.1314
# Epoch 33/300
# 569/569 [==============================] - 0s 43us/step - loss: 0.0511 - mean_absolute_error: 0.1314
# Epoch 34/300
# 569/569 [==============================] - 0s 46us/step - loss: 0.0511 - mean_absolute_error: 0.1315
# Epoch 35/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0511 - mean_absolute_error: 0.1312
# Epoch 36/300
# 569/569 [==============================] - 0s 44us/step - loss: 0.0512 - mean_absolute_error: 0.1319
# Epoch 37/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0511 - mean_absolute_error: 0.1315
# Epoch 38/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0512 - mean_absolute_error: 0.1310
# Epoch 39/300
# 569/569 [==============================] - 0s 43us/step - loss: 0.0510 - mean_absolute_error: 0.1311
# Epoch 40/300
# 569/569 [==============================] - 0s 35us/step - loss: 0.0511 - mean_absolute_error: 0.1320
# Epoch 41/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0511 - mean_absolute_error: 0.1318
# Epoch 42/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0511 - mean_absolute_error: 0.1312
# Epoch 43/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0511 - mean_absolute_error: 0.1308
# Epoch 44/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0511 - mean_absolute_error: 0.1310
# Epoch 45/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0510 - mean_absolute_error: 0.1316
# Epoch 46/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0511 - mean_absolute_error: 0.1311
# Epoch 47/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0510 - mean_absolute_error: 0.1311
# Epoch 48/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0512 - mean_absolute_error: 0.1307
# Epoch 49/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0510 - mean_absolute_error: 0.1312
# Epoch 50/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0511 - mean_absolute_error: 0.1320
# Epoch 51/300
# 569/569 [==============================] - 0s 45us/step - loss: 0.0511 - mean_absolute_error: 0.1313
# Epoch 52/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0511 - mean_absolute_error: 0.1312
# Epoch 53/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0510 - mean_absolute_error: 0.1312
# Epoch 54/300
# 569/569 [==============================] - 0s 43us/step - loss: 0.0511 - mean_absolute_error: 0.1312
# Epoch 55/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0510 - mean_absolute_error: 0.1316
# Epoch 56/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0511 - mean_absolute_error: 0.1307
# Epoch 57/300
# 569/569 [==============================] - 0s 35us/step - loss: 0.0510 - mean_absolute_error: 0.1311
# Epoch 58/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0512 - mean_absolute_error: 0.1311
# Epoch 59/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0510 - mean_absolute_error: 0.1308
# Epoch 60/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0510 - mean_absolute_error: 0.1317
# Epoch 61/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0510 - mean_absolute_error: 0.1315
# Epoch 62/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0510 - mean_absolute_error: 0.1315
# Epoch 63/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0510 - mean_absolute_error: 0.1311
# Epoch 64/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0510 - mean_absolute_error: 0.1309
# Epoch 65/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0511 - mean_absolute_error: 0.1306
# Epoch 66/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0511 - mean_absolute_error: 0.1315
# Epoch 67/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0510 - mean_absolute_error: 0.1313
# Epoch 68/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0511 - mean_absolute_error: 0.1315
# Epoch 69/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0510 - mean_absolute_error: 0.1310
# Epoch 70/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0510 - mean_absolute_error: 0.1307
# Epoch 71/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0509 - mean_absolute_error: 0.1308
# Epoch 72/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0510 - mean_absolute_error: 0.1306
# Epoch 73/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0511 - mean_absolute_error: 0.1322
# Epoch 74/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0511 - mean_absolute_error: 0.1315
# Epoch 75/300
# 569/569 [==============================] - 0s 35us/step - loss: 0.0509 - mean_absolute_error: 0.1309
# Epoch 76/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0511 - mean_absolute_error: 0.1319
# Epoch 77/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0509 - mean_absolute_error: 0.1312
# Epoch 78/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0510 - mean_absolute_error: 0.1308
# Epoch 79/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0511 - mean_absolute_error: 0.1310
# Epoch 80/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0511 - mean_absolute_error: 0.1318
# Epoch 81/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0509 - mean_absolute_error: 0.1310
# Epoch 82/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0510 - mean_absolute_error: 0.1312
# Epoch 83/300
# 569/569 [==============================] - 0s 45us/step - loss: 0.0511 - mean_absolute_error: 0.1305
# Epoch 84/300
# 569/569 [==============================] - 0s 43us/step - loss: 0.0509 - mean_absolute_error: 0.1303
# Epoch 85/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0509 - mean_absolute_error: 0.1310
# Epoch 86/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0509 - mean_absolute_error: 0.1313
# Epoch 87/300
# 569/569 [==============================] - 0s 35us/step - loss: 0.0510 - mean_absolute_error: 0.1309
# Epoch 88/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0509 - mean_absolute_error: 0.1311
# Epoch 89/300
# 569/569 [==============================] - 0s 43us/step - loss: 0.0509 - mean_absolute_error: 0.1313
# Epoch 90/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0509 - mean_absolute_error: 0.1308
# Epoch 91/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0510 - mean_absolute_error: 0.1306
# Epoch 92/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0510 - mean_absolute_error: 0.1314
# Epoch 93/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0509 - mean_absolute_error: 0.1311
# Epoch 94/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0509 - mean_absolute_error: 0.1307
# Epoch 95/300
# 569/569 [==============================] - 0s 46us/step - loss: 0.0509 - mean_absolute_error: 0.1306
# Epoch 96/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0510 - mean_absolute_error: 0.1317
# Epoch 97/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0509 - mean_absolute_error: 0.1309
# Epoch 98/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0510 - mean_absolute_error: 0.1312
# Epoch 99/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0509 - mean_absolute_error: 0.1310
# Epoch 100/300
# 569/569 [==============================] - 0s 46us/step - loss: 0.0510 - mean_absolute_error: 0.1302
# Epoch 101/300
# 569/569 [==============================] - 0s 44us/step - loss: 0.0511 - mean_absolute_error: 0.1317
# Epoch 102/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0510 - mean_absolute_error: 0.1311
# Epoch 103/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0509 - mean_absolute_error: 0.1299
# Epoch 104/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0508 - mean_absolute_error: 0.1307
# Epoch 105/300
# 569/569 [==============================] - 0s 44us/step - loss: 0.0508 - mean_absolute_error: 0.1314
# Epoch 106/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0509 - mean_absolute_error: 0.1317
# Epoch 107/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0509 - mean_absolute_error: 0.1309
# Epoch 108/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0508 - mean_absolute_error: 0.1306
# Epoch 109/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0508 - mean_absolute_error: 0.1308
# Epoch 110/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0509 - mean_absolute_error: 0.1315
# Epoch 111/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0509 - mean_absolute_error: 0.1306
# Epoch 112/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0508 - mean_absolute_error: 0.1301
# Epoch 113/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0509 - mean_absolute_error: 0.1306
# Epoch 114/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0508 - mean_absolute_error: 0.1309
# Epoch 115/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0508 - mean_absolute_error: 0.1311
# Epoch 116/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0508 - mean_absolute_error: 0.1312
# Epoch 117/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0509 - mean_absolute_error: 0.1306
# Epoch 118/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0508 - mean_absolute_error: 0.1304
# Epoch 119/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0512 - mean_absolute_error: 0.1322
# Epoch 120/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0512 - mean_absolute_error: 0.1306
# Epoch 121/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0509 - mean_absolute_error: 0.1309
# Epoch 122/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0509 - mean_absolute_error: 0.1315
# Epoch 123/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0510 - mean_absolute_error: 0.1305
# Epoch 124/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0508 - mean_absolute_error: 0.1299
# Epoch 125/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0508 - mean_absolute_error: 0.1305
# Epoch 126/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0509 - mean_absolute_error: 0.1302
# Epoch 127/300
# 569/569 [==============================] - 0s 43us/step - loss: 0.0507 - mean_absolute_error: 0.1304
# Epoch 128/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0508 - mean_absolute_error: 0.1311
# Epoch 129/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0508 - mean_absolute_error: 0.1306
# Epoch 130/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0508 - mean_absolute_error: 0.1306
# Epoch 131/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0508 - mean_absolute_error: 0.1311
# Epoch 132/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0508 - mean_absolute_error: 0.1314
# Epoch 133/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0508 - mean_absolute_error: 0.1304
# Epoch 134/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0507 - mean_absolute_error: 0.1306
# Epoch 135/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0508 - mean_absolute_error: 0.1306
# Epoch 136/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0509 - mean_absolute_error: 0.1311
# Epoch 137/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0507 - mean_absolute_error: 0.1306
# Epoch 138/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0508 - mean_absolute_error: 0.1300
# Epoch 139/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0508 - mean_absolute_error: 0.1304
# Epoch 140/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0508 - mean_absolute_error: 0.1310
# Epoch 141/300
# 569/569 [==============================] - 0s 35us/step - loss: 0.0507 - mean_absolute_error: 0.1308
# Epoch 142/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0507 - mean_absolute_error: 0.1302
# Epoch 143/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0507 - mean_absolute_error: 0.1303
# Epoch 144/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0507 - mean_absolute_error: 0.1307
# Epoch 145/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0507 - mean_absolute_error: 0.1307
# Epoch 146/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0507 - mean_absolute_error: 0.1310
# Epoch 147/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0507 - mean_absolute_error: 0.1302
# Epoch 148/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0507 - mean_absolute_error: 0.1303
# Epoch 149/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0507 - mean_absolute_error: 0.1303
# Epoch 150/300
# 569/569 [==============================] - 0s 46us/step - loss: 0.0510 - mean_absolute_error: 0.1314
# Epoch 151/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0510 - mean_absolute_error: 0.1303
# Epoch 152/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0508 - mean_absolute_error: 0.1303
# Epoch 153/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0507 - mean_absolute_error: 0.1306
# Epoch 154/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0507 - mean_absolute_error: 0.1309
# Epoch 155/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0509 - mean_absolute_error: 0.1301
# Epoch 156/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0507 - mean_absolute_error: 0.1303
# Epoch 157/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0508 - mean_absolute_error: 0.1310
# Epoch 158/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0507 - mean_absolute_error: 0.1302
# Epoch 159/300
# 569/569 [==============================] - 0s 44us/step - loss: 0.0507 - mean_absolute_error: 0.1304
# Epoch 160/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0506 - mean_absolute_error: 0.1306
# Epoch 161/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0507 - mean_absolute_error: 0.1301
# Epoch 162/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0507 - mean_absolute_error: 0.1306
# Epoch 163/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0509 - mean_absolute_error: 0.1301
# Epoch 164/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0506 - mean_absolute_error: 0.1302
# Epoch 165/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0507 - mean_absolute_error: 0.1307
# Epoch 166/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0507 - mean_absolute_error: 0.1312
# Epoch 167/300
# 569/569 [==============================] - 0s 35us/step - loss: 0.0506 - mean_absolute_error: 0.1304
# Epoch 168/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0507 - mean_absolute_error: 0.1296
# Epoch 169/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0507 - mean_absolute_error: 0.1301
# Epoch 170/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0507 - mean_absolute_error: 0.1304
# Epoch 171/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0506 - mean_absolute_error: 0.1301
# Epoch 172/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0506 - mean_absolute_error: 0.1299
# Epoch 173/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0506 - mean_absolute_error: 0.1301
# Epoch 174/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0507 - mean_absolute_error: 0.1306
# Epoch 175/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0506 - mean_absolute_error: 0.1306
# Epoch 176/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0507 - mean_absolute_error: 0.1304
# Epoch 177/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0506 - mean_absolute_error: 0.1305
# Epoch 178/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0507 - mean_absolute_error: 0.1308
# Epoch 179/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0507 - mean_absolute_error: 0.1298
# Epoch 180/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0506 - mean_absolute_error: 0.1297
# Epoch 181/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0506 - mean_absolute_error: 0.1298
# Epoch 182/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0506 - mean_absolute_error: 0.1305
# Epoch 183/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0507 - mean_absolute_error: 0.1312
# Epoch 184/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0506 - mean_absolute_error: 0.1298
# Epoch 185/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0506 - mean_absolute_error: 0.1291
# Epoch 186/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0507 - mean_absolute_error: 0.1304
# Epoch 187/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0506 - mean_absolute_error: 0.1304
# Epoch 188/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0506 - mean_absolute_error: 0.1307
# Epoch 189/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0506 - mean_absolute_error: 0.1302
# Epoch 190/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0506 - mean_absolute_error: 0.1304
# Epoch 191/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0506 - mean_absolute_error: 0.1300
# Epoch 192/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0506 - mean_absolute_error: 0.1295
# Epoch 193/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0505 - mean_absolute_error: 0.1301
# Epoch 194/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0506 - mean_absolute_error: 0.1307
# Epoch 195/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0505 - mean_absolute_error: 0.1304
# Epoch 196/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0506 - mean_absolute_error: 0.1310
# Epoch 197/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0506 - mean_absolute_error: 0.1298
# Epoch 198/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0505 - mean_absolute_error: 0.1297
# Epoch 199/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0505 - mean_absolute_error: 0.1299
# Epoch 200/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0505 - mean_absolute_error: 0.1300
# Epoch 201/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0505 - mean_absolute_error: 0.1304
# Epoch 202/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0506 - mean_absolute_error: 0.1310
# Epoch 203/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0505 - mean_absolute_error: 0.1303
# Epoch 204/300
# 569/569 [==============================] - 0s 34us/step - loss: 0.0505 - mean_absolute_error: 0.1294
# Epoch 205/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0508 - mean_absolute_error: 0.1308
# Epoch 206/300
# 569/569 [==============================] - 0s 34us/step - loss: 0.0505 - mean_absolute_error: 0.1304
# Epoch 207/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0506 - mean_absolute_error: 0.1297
# Epoch 208/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0505 - mean_absolute_error: 0.1296
# Epoch 209/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0505 - mean_absolute_error: 0.1297
# Epoch 210/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0506 - mean_absolute_error: 0.1296
# Epoch 211/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0505 - mean_absolute_error: 0.1298
# Epoch 212/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0506 - mean_absolute_error: 0.1309
# Epoch 213/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0505 - mean_absolute_error: 0.1307
# Epoch 214/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0505 - mean_absolute_error: 0.1301
# Epoch 215/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0505 - mean_absolute_error: 0.1295
# Epoch 216/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0505 - mean_absolute_error: 0.1298
# Epoch 217/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0505 - mean_absolute_error: 0.1302
# Epoch 218/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0505 - mean_absolute_error: 0.1301
# Epoch 219/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0506 - mean_absolute_error: 0.1299
# Epoch 220/300
# 569/569 [==============================] - 0s 45us/step - loss: 0.0506 - mean_absolute_error: 0.1306
# Epoch 221/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0504 - mean_absolute_error: 0.1302
# Epoch 222/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0505 - mean_absolute_error: 0.1299
# Epoch 223/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0507 - mean_absolute_error: 0.1306
# Epoch 224/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0505 - mean_absolute_error: 0.1298
# Epoch 225/300
# 569/569 [==============================] - 0s 49us/step - loss: 0.0505 - mean_absolute_error: 0.1295
# Epoch 226/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0504 - mean_absolute_error: 0.1296
# Epoch 227/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0505 - mean_absolute_error: 0.1303
# Epoch 228/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0504 - mean_absolute_error: 0.1300
# Epoch 229/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0505 - mean_absolute_error: 0.1294
# Epoch 230/300
# 569/569 [==============================] - 0s 45us/step - loss: 0.0505 - mean_absolute_error: 0.1293
# Epoch 231/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0506 - mean_absolute_error: 0.1306
# Epoch 232/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0505 - mean_absolute_error: 0.1300
# Epoch 233/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0504 - mean_absolute_error: 0.1298
# Epoch 234/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0504 - mean_absolute_error: 0.1295
# Epoch 235/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0505 - mean_absolute_error: 0.1300
# Epoch 236/300
# 569/569 [==============================] - 0s 46us/step - loss: 0.0505 - mean_absolute_error: 0.1297
# Epoch 237/300
# 569/569 [==============================] - 0s 46us/step - loss: 0.0506 - mean_absolute_error: 0.1304
# Epoch 238/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0505 - mean_absolute_error: 0.1305
# Epoch 239/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0504 - mean_absolute_error: 0.1298
# Epoch 240/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0505 - mean_absolute_error: 0.1299
# Epoch 241/300
# 569/569 [==============================] - 0s 46us/step - loss: 0.0504 - mean_absolute_error: 0.1294
# Epoch 242/300
# 569/569 [==============================] - 0s 46us/step - loss: 0.0504 - mean_absolute_error: 0.1297
# Epoch 243/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0504 - mean_absolute_error: 0.1299
# Epoch 244/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0504 - mean_absolute_error: 0.1300
# Epoch 245/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0504 - mean_absolute_error: 0.1295
# Epoch 246/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0504 - mean_absolute_error: 0.1296
# Epoch 247/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0504 - mean_absolute_error: 0.1295
# Epoch 248/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0505 - mean_absolute_error: 0.1303
# Epoch 249/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0503 - mean_absolute_error: 0.1299
# Epoch 250/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0505 - mean_absolute_error: 0.1295
# Epoch 251/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0504 - mean_absolute_error: 0.1303
# Epoch 252/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0504 - mean_absolute_error: 0.1298
# Epoch 253/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0505 - mean_absolute_error: 0.1300
# Epoch 254/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0504 - mean_absolute_error: 0.1299
# Epoch 255/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0505 - mean_absolute_error: 0.1293
# Epoch 256/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0504 - mean_absolute_error: 0.1294
# Epoch 257/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0505 - mean_absolute_error: 0.1295
# Epoch 258/300
# 569/569 [==============================] - 0s 36us/step - loss: 0.0503 - mean_absolute_error: 0.1292
# Epoch 259/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0504 - mean_absolute_error: 0.1300
# Epoch 260/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0503 - mean_absolute_error: 0.1296
# Epoch 261/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0504 - mean_absolute_error: 0.1301
# Epoch 262/300
# 569/569 [==============================] - 0s 43us/step - loss: 0.0503 - mean_absolute_error: 0.1296
# Epoch 263/300
# 569/569 [==============================] - 0s 44us/step - loss: 0.0503 - mean_absolute_error: 0.1293
# Epoch 264/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0503 - mean_absolute_error: 0.1298
# Epoch 265/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0503 - mean_absolute_error: 0.1302
# Epoch 266/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0505 - mean_absolute_error: 0.1293
# Epoch 267/300
# 569/569 [==============================] - 0s 43us/step - loss: 0.0504 - mean_absolute_error: 0.1296
# Epoch 268/300
# 569/569 [==============================] - 0s 45us/step - loss: 0.0503 - mean_absolute_error: 0.1295
# Epoch 269/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0504 - mean_absolute_error: 0.1291
# Epoch 270/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0503 - mean_absolute_error: 0.1294
# Epoch 271/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0503 - mean_absolute_error: 0.1303
# Epoch 272/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0504 - mean_absolute_error: 0.1302
# Epoch 273/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0503 - mean_absolute_error: 0.1290
# Epoch 274/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0503 - mean_absolute_error: 0.1286
# Epoch 275/300
# 569/569 [==============================] - 0s 42us/step - loss: 0.0504 - mean_absolute_error: 0.1293
# Epoch 276/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0507 - mean_absolute_error: 0.1310
# Epoch 277/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0504 - mean_absolute_error: 0.1294
# Epoch 278/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0503 - mean_absolute_error: 0.1287
# Epoch 279/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0505 - mean_absolute_error: 0.1302
# Epoch 280/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0503 - mean_absolute_error: 0.1301
# Epoch 281/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0503 - mean_absolute_error: 0.1292
# Epoch 282/300
# 569/569 [==============================] - 0s 37us/step - loss: 0.0503 - mean_absolute_error: 0.1290
# Epoch 283/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0504 - mean_absolute_error: 0.1285
# Epoch 284/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0504 - mean_absolute_error: 0.1298
# Epoch 285/300
# 569/569 [==============================] - 0s 43us/step - loss: 0.0503 - mean_absolute_error: 0.1299
# Epoch 286/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0505 - mean_absolute_error: 0.1289
# Epoch 287/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0503 - mean_absolute_error: 0.1294
# Epoch 288/300
# 569/569 [==============================] - 0s 35us/step - loss: 0.0503 - mean_absolute_error: 0.1299
# Epoch 289/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0505 - mean_absolute_error: 0.1291
# Epoch 290/300
# 569/569 [==============================] - 0s 46us/step - loss: 0.0502 - mean_absolute_error: 0.1291
# Epoch 291/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0503 - mean_absolute_error: 0.1290
# Epoch 292/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0503 - mean_absolute_error: 0.1294
# Epoch 293/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0503 - mean_absolute_error: 0.1299
# Epoch 294/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0505 - mean_absolute_error: 0.1293
# Epoch 295/300
# 569/569 [==============================] - 0s 43us/step - loss: 0.0502 - mean_absolute_error: 0.1295
# Epoch 296/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0502 - mean_absolute_error: 0.1291
# Epoch 297/300
# 569/569 [==============================] - 0s 38us/step - loss: 0.0502 - mean_absolute_error: 0.1295
# Epoch 298/300
# 569/569 [==============================] - 0s 41us/step - loss: 0.0504 - mean_absolute_error: 0.1293
# Epoch 299/300
# 569/569 [==============================] - 0s 40us/step - loss: 0.0503 - mean_absolute_error: 0.1299
# Epoch 300/300
# 569/569 [==============================] - 0s 39us/step - loss: 0.0503 - mean_absolute_error: 0.1296

# %%
guesses = classify(model, x_bc)
tn = 0 #True negative
tp = 0 #True positive
fp = 0 #False positive
fn = 0 #False negative

for i in range(len(y_bc)):
  if y_bc[i] == 0 and guesses[i][0] == 0:
    tn += 1
  elif y_bc[i] == 1 and guesses[i][0] == 1:
    tp += 1
  elif y_bc[i] == 0 and guesses[i][0] == 1:
    fp += 1
  else:
    fn += 1

print("        Guesses:   Benign    Malignant")
print("Truth")
print("Benign:              {}          {}".format(tn, fp))
print("Malignant:           {}          {}".format(fn, tp))
# Out:
#         Guesses:   Benign    Malignant
# Truth
# Benign:              186          26
# Malignant:           11          346
